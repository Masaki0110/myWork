# %% [markdown]
# <a href="https://colab.research.google.com/github/Masaki0110/ds2wsCode/blob/main/nttdata_groupwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ID=int(input("IDを入力してください。")) # ID入力

names=["hujita koki","tanaka sakura","koike juriko"]
ids=[2988,2345,2056]

for i in range(len(ids)):
  if ID == ids[i]:
    I = i

# 認証
if ID in ids:
  question0=int(input(names[I]+"さんでお間違いないでしょうか？　１：はい　２：いいえ")) # 本人確認
  if question0 == 2:
    print("ご利用いただけません。")
else:
  print("ご利用いただけません。")
# Out:
# IDを入力してください。23456
# ご利用いただけません。

# %%
print("おすすめの昼食はこれだ！")

print("今日のメニューはこちら")

menu = [["ビタミンCを取ってください。","鰹のたたき定食＋小松菜あえ","630円"], ["肉体的な疲労ですね。回復力アップ！","レバニラ定食","520円"],["午後もがんばれ！栄養バランス抜群！","幕の内弁当","480円"], ["炭水化物をとって午後も頑張ろう！","鯖の塩焼き定食ごはん大盛り","470円"],["腹持ちよし！","親子丼大盛り","550円"], ["午後も集中！","バナナサンドと豆乳","500円"]]

for menu1 in menu:
  print(menu1)

print("アンケートを開始します")


question1 = int(input('最近、疲れを感じますか？１：はい　2：いいえ　3：まぁまぁ'))

if question1 == 1:
  question1_1 = int(input('精神的な疲労ですか？１：はい　2：いいえ'))
  if question1_1 == 1:
    i = 0
  else:
    i = 1

elif question1 == 2:
  question1_2 = int(input('勉強のやる気はありますか？１：はい　2：いいえ'))
  if question1_2 == 1:
    i = 2
  else:
    i = 3
else:
  question1_3 = int(input('今日はアルバイトですか？１：はい　2：いいえ'))
  if question1_3 == 1:
    i = 4
  else:
    i = 5

print(menu[i][0])
print(menu[i][1] + menu[i][2])
# Out:
# おすすめの昼食はこれだ！
# 今日のメニューはこちら
# ['ビタミンCを取ってください。', '鰹のたたき定食＋小松菜あえ', '630円']
# ['肉体的な疲労ですね。回復力アップ！', 'レバニラ定食', '520円']
# ['午後もがんばれ！栄養バランス抜群！', '幕の内弁当', '480円']
# ['炭水化物をとって午後も頑張ろう！', '鯖の塩焼き定食ごはん大盛り', '470円']
# ['腹持ちよし！', '親子丼大盛り', '550円']
# ['午後も集中！', 'バナナサンドと豆乳', '500円']
# アンケートを開始します
# 最近、疲れを感じますか？１：はい　2：いいえ　3：まぁまぁ1
# 精神的な疲労ですか？１：はい　2：いいえ1
# ビタミンCを取ってください。
# 鰹のたたき定食＋小松菜あえ630円

# %%
details1=["鰹のたたき，ごはん，みそ汁，小松菜あえ","レバニラ，ごはん，みそ汁","鮭，きんぴらごぼう，たくあん，エビフライ","鯖の塩焼き，ごはん，みそ汁","鳥，卵，ごはん","1バナナサンド，豆乳"] # 献立
print(details1[i])

details2=[["カロリー:585kcal","アレルギー物質:大豆,小麦,柑橘類,魚介類,ゴマ,醤油"], ["カロリー:797kcal","アレルギー物質:豚肉,小麦・大豆,ごま,卵"],["カロリー:855kcal","アレルギー物質:小麦,卵,乳,牛肉,鯖,大豆,鶏肉,豚肉,リンゴ,ゼラチン,ごま"], ["カロリー:915kcal","アレルギー物質:鯖,大豆,小麦,ごま"],["カロリー:650kcal","アレルギー物質:卵,小麦,大豆,鶏肉"], ["カロリー:660kcal","アレルギー物質:小麦,乳,卵,大豆"]]

question2=int(input("さらに詳細を表示しますか？ １：はい　2：いいえ"))
if question2 == 1:
  print(menu[i][1])
  print(details2[i])
# Out:
# 鰹のたたき，ごはん，みそ汁，小松菜あえ
# さらに詳細を表示しますか？ １：はい　2：いいえ1
# 鰹のたたき定食＋小松菜あえ
# ['カロリー:585kcal', 'アレルギー物質:大豆,小麦,柑橘類,魚介類,ゴマ,醤油']

# %%
flag=True
count=1
menulist=[]
answer=i
def reorder(count):
  for menu1 in menu:
    menulist.append(count)
    menulist.append(menu1)
    print(menulist)
    menulist.clear()
    count+=1

  answer=int(input("メニューの数字を入力してください"))-1
  return answer

while flag==True:
  order=int(input(f"ご注文は{menu[answer][1] + menu[answer][2]}でよろしいですか 1:はい,2：いいえ"))
  if order==1:
    print("注文を確定します。")
    flag=False
  if order==2:
    print("選び直してください")
    answer=reorder(count)
# Out:
# ご注文は鰹のたたき定食＋小松菜あえ630円でよろしいですか 1:はい,2：いいえ2
# 選び直してください
# [1, ['ビタミンCを取ってください。', '鰹のたたき定食＋小松菜あえ', '630円']]
# [2, ['肉体的な疲労ですね。回復力アップ！', 'レバニラ定食', '520円']]
# [3, ['午後もがんばれ！栄養バランス抜群！', '幕の内弁当', '480円']]
# [4, ['炭水化物をとって午後も頑張ろう！', '鯖の塩焼き定食ごはん大盛り', '470円']]
# [5, ['腹持ちよし！', '親子丼大盛り', '550円']]
# [6, ['午後も集中！', 'バナナサンドと豆乳', '500円']]
# メニューの数字を入力してください2
# ご注文はレバニラ定食520円でよろしいですか 1:はい,2：いいえ1
# 注文を確定します。

# %%
# 支払い方法選択
pay=["現金","クレジット決済","電子マネー"]

while(1):
  payment = int(input("お支払方法を選んでください。１：現金 ２：クレジット決済 ３：電子マネー決済"))
  ans = int(input(pay[payment-1]+"でよろしいでしょうか？　１：はい　２：いいえ"))
  if ans == 2:
    continue

  if payment == 1:
    print("機械にお金を入れてください。")
  elif payment == 2:
    print("カードを挿入してください。")
  else:
    print("タッチしてください。")

  if ans == 1: break

print("支払いが完了しました。") # 支払い完了
